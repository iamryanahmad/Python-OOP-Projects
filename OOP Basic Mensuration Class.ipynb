# %%
class mensuration:
    def __init__(self):
        print('Warning! units entered must be under same denominations. Internal converstion is disabled.')
        self.menu()
    def menu(self):
        user = input('''Hello! How can I help you with your mensuration problem?
        
                    1 - Understanding concepts
                    2 - Calculating area
                    3 - Calculating perimeter
                    4 - Calculating volume 
                    5 - Exit
                    ''')
        if user=='1':
            print()
            print("""Mensuration: 
            The branch of Mathematics that concerns with measurement of lengths,
            areas and volume of plane figure and solid figures is called Mensuration.\n""")
            print('-'*100)
            print()
            print('''Area:
            The magnitude of a region occupied by a figure in a plane
            is called its area. Area is measured in m2.\n''')
            print('-'*100)
            print()
            print('''Volume:
            The magnitude of region occupied by solid is space is called its volume.
            Volume is measures in m3 (meter cube) or l (liters).\n''')
            print('-'*100)
            print()
            print('''Perimeter: 
            Total length of the boundary of a plane figure is called its perimeter. 
            Perimeter of the circle is called circumference.\n''')
            print('-'*100)
            print()
            print('''Surface area: 
            The area of the surface of the solid figure is called its surface 
            area.\n''')
            print()
            print('*'*100)
            print()
            print('--------------------------AREA AND PERIMETER OF PLANE FIGURE--------------------------\n')
            print()
            print('''TRIANGLE: 
            a, b, c are the side h is altitude and s is the semi-perimeter, 
            S = a+b+c / 2  \n''')
            print('''Perimeter: 2*S\n''')
            print('''Area: 1/2 * Base * Height\n ''')
            print()
            print('''RECTANGLE: 
            a is length and b is breadth\n''')
            print('''Perimeter: 2(a+b)\n''')
            print('''Area: Length * Breadth\n''')
            print()
            print(''''SQUARE: 
            a is a side\n''')
            print('Perimeter: 4*a\n')
            print('Area: (a)^2\n')
            print()
            print('''PARALLELOGRAM: 
            a and b are parallel sides, h is the distance between parallel length of a\n ''')
            print('Perimeter: 2(a+b)\n''')
            print('Area: side * height\n')
            print()
            print('RHOMBUS: a is side d1, d2 are the diagonals\n')
            print('Perimeter: 4a\n')
            print('Area: 1/2 × product of diagonal 1/2 *d1*d2\n')
            print()
            print('TRAPEZIUM: a, b are parallel sides h is distance between them\n')
            print('Perimeter: Sum of all sides\n')
            print('Area: 1/2 * Sum of parallel side * height 1/2 (a+b)*h \n ')
            print()
            print('CIRCLE: r is radius, 2*r is diameter\n ')
            print('Circumfrence: 2 *π *r\n ')
            print('Area: π *r^2\n')
            print()
            print('--------------------------Area and Volume of Plane Figure--------------------------\n')
            print()
            print('SHAPE: Cuboid\n')
            print('Surface Area: 2(l*b + b*h +l*h) l= length, b=breadth, h=height \n')
            print('Volume: lbh\n')
            print()
            print('SHAPE: Cube\n')
            print('Surface Area: 6*a*2\n')
            print('Volume: a^3')
            print()
            print('SHAPE: Cylinder\n')
            print('Surface Area: 2*π*r(h+r), r = radius of circular bases, h = height of cylinder \n')
            print('Volume: π*r*2*h ')
            print()
            print('SHAPE: Cone\n')
            print('Surface Area: πr(l+r), r=radius of base, l=slant height Also, l2=h2+r2, where h is the height of cone\n')
            print('Volume: (1/3)*π*r*2*h\n')
            print()
            print('SHAPE: Sphere\n')
            print('Surface Area: 4*π*r*2 \n')
            print('Volume: 	(4/3)*π*r*3 \n')
            task = input('Press 1 to back: ')
            if task == '1':
                print('*'*50)
                self.menu()
            else:
                print('Bye!')
                

            
        if user=='2':
            figure = input('''Please select a shape:
                        1- Triangle 
                        2- Rectangle
                        3- Square
                        4- Parallelogram
                        5- Rhombus
                        6- Trapezium
                        7- Circle
                        8- Cuboid
                        9- Cube
                        10- Cylinder
                        11- Cone
                        12- Sphere''')
                        
            if figure=='1':
                self.triangle_area()
            elif figure=='2':
                self.rectangle_area()
            elif figure=='3':
                self.square_area()
            elif figure=='4':
                self.prallelogram_area()
            elif figure=='5':
                self.rhombus_area()
            elif figure=='6':
                self.trapezium_area()
            elif figure=='7':
                self.circle_area()
            elif figure=='8':
                self.cuboid_area()
            elif figure=='9':
                self.cube_area()
            elif figure=='10':
                self.cylinder_area()
            elif figure=='11':
                self.cone_area()
            elif figure=='12':
                self.sphere_area()
        
        if user=='3':
            figure = input('''Please select a shape:
                        1- Triangle 
                        2- Rectangle
                        3- Square
                        4- Parallelogram
                        5- Rhombus
                        6- Trapezium
                        7- Circle
                           ''')
            if figure=='1':
                self.triangle_perimeter()
            elif figure=='2':
                self.rectangle_perimeter()
            elif figure=='3':
                self.square_perimeter()
            elif figure=='4':
                self.parallelogram_perimeter()
            elif figure=='5':
                self.rhombus_perimeter()
            elif figure=='6':
                self.trapezium_perimeter()
            elif figure=='7':
                self.circle_perimeter()
        
        if user=='4':
            figure = input('''Please select a shape:
                        1- Cuboid
                        2- Cube
                        3- Cylinder
                        4- Cone
                        5- Sphere
                           ''')
            if figure=='1':
                self.cuboid_volume()
            elif figure=='2':
                self.cube_volume()
            elif figure=='3':
                self.cylinder_volume()
            elif figure=='4':
                self.cone_volume()
            elif figure=='5':
                self.sphere_volume()
        
        if user=='5':
            print('Bye!')
    
    def triangle_area(self):
        values = list(map(lambda x: int(x),input('Enter Base and Height: ').split()))
        area = 0.5*(values[0]*values[1])
        print('Area of the triange: ',area)
        self.menu()
    def rectangle_area(self):
        values = list(map(lambda x: int(x),input('Enter Length and Breadth: ').split()))
        area = values[0]*values[1]
        print('Area of the rectangle:',area)
        self.menu()
    def square_area(self):
        values = list(map(lambda x: int(x),input('Enter Side: ').split()))
        area = a**2
        print('Area of the square:',area)
        self.menu()
    def parallelogram_area(self):
        values = list(map(lambda x: int(x),input('Enter Side and Height: ').split()))
        area = values[0]*values[1]
        print('Area of the parallelogram:',area)
        self.menu()
    def rhombus_area(self):
        values = list(map(lambda x: int(x),input('Enter Diagonals: ').split()))
        area = 0.5*(values[0]*values[1])
        print('Area of Rhombus:',area)
        self.menu()
    def trapezium_area(self):
        values = list(map(lambda x: int(x),input('Enter the Sides and Height: ').split()))
        area = 0.5*(values[0]+values[1])*values[2]
        print('Area of Trapezium:',area)
        self.menu()
    def circle_area(self):
        values = list(map(lambda x: int(x),input('Enter Radius: ').split()))
        area = 3.14*(values[0]**2)
        print('Area of Circle:',area)
        self.menu()
    def cuboid_area(self):
        values = list(map(lambda x: int(x),input('Enter Length Breadth and Height: ').split()))
        area = values[0]*values[1]*values[2]
        print('Surface Area of Cuboid:',area)
        self.menu()
    def cube_area(self):
        values = list(map(lambda x: int(x),input('Enter Edge: ').split()))
        area = (6*values[0])**2
        print('Surface Area of Cube:',area)
        self.menu()
    def cylinder_area(self):
        values = list(map(lambda x: int(x),input('Enter Radius and Height: ').split()))
        area = 2*3.14*values[0]*(values[0]+values[1])
        print('Surface Area of Cylinder:',area)
        self.menu()
    def cone_area(self):
        values = list(map(lambda x: int(x),input('Enter Radius and Slant Height: ').split()))
        area = 3.14*values[0](values[0] + values[1])
        print('Surface Area of Cone:',area)
        self.menu()
    def sphere_area(self):
        values = list(map(lambda x: int(x),input('Enter Radius: ').split()))
        area = 4*3.14*(values[0]**2)
        print('Surface Area of Sphere:',area)
        self.menu()
        
    
    def triangle_perimeter(self):
        values = list(map(lambda x: int(x),input('Enter Sides: ').split()))
        perimeter = sum(values)
        print('Perimeter of Triangle:',perimeter)
        self.menu()
    def rectangle_perimeter(self):
        values = list(map(lambda x: int(x),input('Enter Length and Breadth: ').split()))
        perimeter = sum(values)*2
        print('Perimeter of Rectangle:',perimeter)
        self.menu()
    def square_perimeter(self):
        values = list(map(lambda x: int(x),input('Enter Side: ').split()))
        perimeter = 4*values[0]
        print('Perimeter of Square:',perimeter)
        self.menu()
    def parallelogram_perimeter(self):
        values = list(map(lambda x: int(x),input('Enter Sides: ').split()))
        perimeter = 2*sum(values)
        print('Perimeter of Parallelogram:',perimeter)
        self.menu()
    def rhombus_perimeter(self):
        values = list(map(lambda x: int(x),input('Enter Side: ').split()))
        perimeter = 4*values[0]
        print('Perimeter of Rhombus:',perimeter)
        self.menu()
    def trapezium_perimeter(self):
        values = list(map(lambda x: int(x),input('Enter Sides: ').split()))
        perimeter = sum(values)
        print('Perimeter of Trapezium:',perimeter)
        self.menu()
    def circle_perimeter(self):
        values = list(map(lambda x: int(x),input('Enter Radius: ').split()))
        perimeter = 2*3.14*values[0]
        print('Perimeter of Triangle:',perimeter)
        self.menu()
    
    
    def cuboid_volume(self):
        values = list(map(lambda x: int(x),input('Enter Length, Breadth and Height: ').split()))
        perimeter = values[0]*values[1]*values[2]
        print('Volume of Cuboid:',perimeter)
        self.menu()
    def cube_volume(self):
        values = list(map(lambda x: int(x),input('Enter Side: ').split()))
        perimeter = values[0]**3
        print('Volume of Cube:',perimeter)
        self.menu()
    def cylinder_volume(self):
        values = list(map(lambda x: int(x),input('Enter Radius and Height: ').split()))
        perimeter = values[1]*3.14*values[0]**2
        print('Volume of Cylinder:',perimeter)
        self.menu()
    def cone_volume(self):
        values = list(map(lambda x: int(x),input('Enter Radius and Height: ').split()))
        perimeter = (3.14*values[0]**2*values[1])*1/3
        print('Volume of Cone:',perimeter)
        self.menu()
    def sphere_volume(self):
        values = list(map(lambda x: int(x),input('Enter Radius: ').split()))
        perimeter = (values[0]**3)*3.14*4/3
        print('Volume of Sphere:',perimeter)
        self.menu()
